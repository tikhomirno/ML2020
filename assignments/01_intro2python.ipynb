# %% [markdown]
# #  Основные манипуляции
#
# Jupyter notebooks - это ...
#
# Как запустить?
#
# Зачем?

# %%
import numpy as np

# %% [markdown]
# ## Типы данных
#
# Зачем нужно типизировать данные?

# %% [markdown]
# ### Числовые

# %% [markdown]
# ### Логические

# %% [markdown]
# ### None

# %% [markdown]
# ### Строковые

# %% [markdown]
#  ## Массивы

# %% [markdown]
# ### Списки

# %% [markdown]
# ### Кортежи

# %% [markdown]
# ### Множества

# %% [markdown]
# ### Cловари

# %%
## Задание: заполнить тетрадку примерами, привести ситуацию когда эт
